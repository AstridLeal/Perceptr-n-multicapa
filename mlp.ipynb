# %% [markdown]
# # Práctica 1: Perceptrón multicapa.
#
# Tu jefe pidió a RH que recolectara datos de desempeño de tus compañeros, los resultados se almacenaron en un csv. El punto critico de estos datos es la satisfacción del empleado, entonces ¿Podremos estimar la satisfacción de los empleados con los datos recabados?.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
from tensorflow.keras import layers, models


df = pd.read_csv('Extended_Employee_Performance_and_Productivity_Data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Employee_ID                  100000 non-null  int64
#  1   Department                   100000 non-null  object
#  2   Gender                       100000 non-null  object
#  3   Age                          100000 non-null  int64
#  4   Job_Title                    100000 non-null  object
#  5   Hire_Date                    100000 non-null  object
#  6   Years_At_Company             100000 non-null  int64
#  7   Education_Level              100000 non-null  object
#  8   Performance_Score            100000 non-null  int64
#  9   Monthly_Salary               100000 non-null  float64
#  10  Work_Hours_Per_Week          100000 non-null  int64
#  11  Projects_Handled             100000 non-null  int64
#  12  Overtime_Hours               100000 non-null  int64
#  13  Sick_Days                    100000 non-null  int64
#  14  Remote_Work_Frequency        100000 non-null  int64
#  15  Team_Size                    100000 non-null  int64
#  16  Training_Hours               100000 non-null  int64
#  17  Promotions                   100000 non-null  int64
#  18  Employee_Satisfaction_Score  100000 non-null  float64
#  19  Resigned                     100000 non-null  bool
# dtypes: bool(1), float64(2), int64(12), object(5)
# memory usage: 14.6+ MB

# %%
# Filtrar las columnas numéricas
numeric_columns = df.select_dtypes(include=['number']).drop('Employee_ID',axis=1)


# Si numeric_columns es un Index, conviértelo a lista
cols = list(numeric_columns)

fig, axes = plt.subplots(1, len(cols), figsize=(5 * len(cols), 4))

for i, col in enumerate(cols):
    axes[i].hist(df[col], bins=20, color='skyblue', edgecolor='black')
    axes[i].set_title(col)
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Problemas**, tenemos distribuciones con picos, esos nos indica categorías. Por otro lado, tenemos variables con "valles" en su distribución (distribuciones multimodales) por lo que resultaría óptimo aplicar técnicas de feature engeneering. Por último tenemos distribuciones uniformes, por lo que cada una requeriría un procesamiento indivudual, hagamos la vista gorda e intentemos ajustar un MLP con estos datos, solo estandaricemos nuestros datos.

# %% [markdown]
# ---
#
# ## Implementación de Red:
#
# To**memos los datos numéricos como nuestra variable X, y la variable objetivo como ***'Employee_Satisfaction_Score'***.
# - **Actividad 1**: Para todos los strings ``'@modif@'`` que aparescan en el siguiente bloque de código cámbialos para que el código funcione.

# %%
X = numeric_columns.drop('Employee_Satisfaction_Score',axis = 1)
y = numeric_columns['Employee_Satisfaction_Score']
y = y.apply(lambda x: round(x)-1) #Cambiamos la variable objetivo a 5 categorías numéricas

scaler = StandardScaler()
X_standar = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_standar, y, test_size=0.33, random_state=42)

y_onehot_train = tf.keras.utils.to_categorical(y_train, 5)
y_onehot_test = tf.keras.utils.to_categorical(y_test,5)

# %% [markdown]
# - **Actividad 2:** Implementa 3 arquitecturas de MLP, cada una con su propio nombre, cambiando la estructura de dichas arquitecturas (capas, neuronas por capa, función de activación, etc).

# %%
# En las siguientes celdas, construye tu modelo con tensorflow.keras solo la arquitectura

# %%
MLP_Basico = models.Sequential([
    layers.Input(shape=(X_train.shape[1],)),
    layers.Dense(32, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(5, activation='softmax')
])

# %%
MLP_Intermedio = models.Sequential([
    layers.Input(shape=(X_train.shape[1],)),
    layers.Dense(64, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(5, activation='softmax')
])

# %%
MLP_Avanzado = models.Sequential([
    layers.Input(shape=(X_train.shape[1],)),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(64, activation='tanh'),
    layers.Dense(32, activation='relu'),
    layers.Dense(5, activation='softmax')
])

# %% [markdown]
# - **Actividad 3:** Compila y ajusta tus tres modelos con sus respectivos hiperparámetros.

# %%
# En las siguientes celdas, compila y entrena el modelo

# %%
MLP_Basico.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history_basico = MLP_Basico.fit(
    X_train,
    y_onehot_train,
    epochs=20,
    batch_size=64,
    validation_data=(X_test, y_onehot_test)
)
# Out:
# Epoch 1/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.2498 - loss: 1.5674 - val_accuracy: 0.2543 - val_loss: 1.5602
# Epoch 2/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2569 - loss: 1.5569 - val_accuracy: 0.2533 - val_loss: 1.5585
# Epoch 3/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2586 - loss: 1.5553 - val_accuracy: 0.2545 - val_loss: 1.5580
# Epoch 4/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2617 - loss: 1.5547 - val_accuracy: 0.2535 - val_loss: 1.5585
# Epoch 5/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2623 - loss: 1.5542 - val_accuracy: 0.2518 - val_loss: 1.5580
# Epoch 6/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2646 - loss: 1.5536 - val_accuracy: 0.2565 - val_loss: 1.5583
# Epoch 7/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2640 - loss: 1.5533 - val_accuracy: 0.2513 - val_loss: 1.5594
# Epoch 8/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2659 - loss: 1.5530 - val_accuracy: 0.2538 - val_loss: 1.5588
# Epoch 9/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2668 - loss: 1.5526 - val_accuracy: 0.2553 - val_loss: 1.5591
# Epoch 10/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2681 - loss: 1.5522 - val_accuracy: 0.2536 - val_loss: 1.5588
# Epoch 11/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2705 - loss: 1.5519 - val_accuracy: 0.2585 - val_loss: 1.5594
# Epoch 12/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2685 - loss: 1.5516 - val_accuracy: 0.2570 - val_loss: 1.5596
# Epoch 13/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2704 - loss: 1.5512 - val_accuracy: 0.2550 - val_loss: 1.5601
# Epoch 14/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2709 - loss: 1.5509 - val_accuracy: 0.2541 - val_loss: 1.5601
# Epoch 15/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2704 - loss: 1.5505 - val_accuracy: 0.2577 - val_loss: 1.5600
# Epoch 16/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2731 - loss: 1.5503 - val_accuracy: 0.2548 - val_loss: 1.5607
# Epoch 17/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2730 - loss: 1.5501 - val_accuracy: 0.2574 - val_loss: 1.5607
# Epoch 18/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2727 - loss: 1.5497 - val_accuracy: 0.2552 - val_loss: 1.5613
# Epoch 19/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2745 - loss: 1.5493 - val_accuracy: 0.2545 - val_loss: 1.5621
# Epoch 20/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2738 - loss: 1.5492 - val_accuracy: 0.2564 - val_loss: 1.5622

# %%
MLP_Intermedio.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history_intermedio = MLP_Intermedio.fit(
    X_train,
    y_onehot_train,
    epochs=30,
    batch_size=64,
    validation_data=(X_test, y_onehot_test)
)
# Out:
# Epoch 1/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.2526 - loss: 1.5599 - val_accuracy: 0.2513 - val_loss: 1.5617
# Epoch 2/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2608 - loss: 1.5555 - val_accuracy: 0.2521 - val_loss: 1.5586
# Epoch 3/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2642 - loss: 1.5544 - val_accuracy: 0.2523 - val_loss: 1.5589
# Epoch 4/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2671 - loss: 1.5533 - val_accuracy: 0.2515 - val_loss: 1.5589
# Epoch 5/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2711 - loss: 1.5523 - val_accuracy: 0.2543 - val_loss: 1.5598
# Epoch 6/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2731 - loss: 1.5512 - val_accuracy: 0.2549 - val_loss: 1.5596
# Epoch 7/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2768 - loss: 1.5499 - val_accuracy: 0.2515 - val_loss: 1.5631
# Epoch 8/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2807 - loss: 1.5485 - val_accuracy: 0.2541 - val_loss: 1.5619
# Epoch 9/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2823 - loss: 1.5468 - val_accuracy: 0.2542 - val_loss: 1.5640
# Epoch 10/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2843 - loss: 1.5453 - val_accuracy: 0.2537 - val_loss: 1.5641
# Epoch 11/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2893 - loss: 1.5434 - val_accuracy: 0.2530 - val_loss: 1.5667
# Epoch 12/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2899 - loss: 1.5417 - val_accuracy: 0.2531 - val_loss: 1.5680
# Epoch 13/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2913 - loss: 1.5395 - val_accuracy: 0.2560 - val_loss: 1.5721
# Epoch 14/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2964 - loss: 1.5373 - val_accuracy: 0.2496 - val_loss: 1.5723
# Epoch 15/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2984 - loss: 1.5362 - val_accuracy: 0.2526 - val_loss: 1.5749
# Epoch 16/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3002 - loss: 1.5340 - val_accuracy: 0.2526 - val_loss: 1.5739
# Epoch 17/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3020 - loss: 1.5321 - val_accuracy: 0.2549 - val_loss: 1.5778
# Epoch 18/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3030 - loss: 1.5305 - val_accuracy: 0.2528 - val_loss: 1.5792
# Epoch 19/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3055 - loss: 1.5284 - val_accuracy: 0.2533 - val_loss: 1.5809
# Epoch 20/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3092 - loss: 1.5265 - val_accuracy: 0.2504 - val_loss: 1.5836
# Epoch 21/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3091 - loss: 1.5244 - val_accuracy: 0.2521 - val_loss: 1.5841
# Epoch 22/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3102 - loss: 1.5231 - val_accuracy: 0.2531 - val_loss: 1.5827
# Epoch 23/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3135 - loss: 1.5216 - val_accuracy: 0.2489 - val_loss: 1.5890
# Epoch 24/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3163 - loss: 1.5198 - val_accuracy: 0.2491 - val_loss: 1.5923
# Epoch 25/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3156 - loss: 1.5187 - val_accuracy: 0.2527 - val_loss: 1.5938
# Epoch 26/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3185 - loss: 1.5168 - val_accuracy: 0.2504 - val_loss: 1.5916
# Epoch 27/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3192 - loss: 1.5156 - val_accuracy: 0.2517 - val_loss: 1.5938
# Epoch 28/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3204 - loss: 1.5142 - val_accuracy: 0.2508 - val_loss: 1.5968
# Epoch 29/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3205 - loss: 1.5129 - val_accuracy: 0.2497 - val_loss: 1.5985
# Epoch 30/30
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3208 - loss: 1.5116 - val_accuracy: 0.2534 - val_loss: 1.5973

# %%
MLP_Avanzado.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history_avanzado = MLP_Avanzado.fit(
    X_train,
    y_onehot_train,
    epochs=40,
    batch_size=128,
    validation_data=(X_test, y_onehot_test)
)
# Out:
# Epoch 1/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.2494 - loss: 1.5675 - val_accuracy: 0.2532 - val_loss: 1.5584
# Epoch 2/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2552 - loss: 1.5579 - val_accuracy: 0.2560 - val_loss: 1.5578
# Epoch 3/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2567 - loss: 1.5565 - val_accuracy: 0.2515 - val_loss: 1.5583
# Epoch 4/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2597 - loss: 1.5557 - val_accuracy: 0.2507 - val_loss: 1.5581
# Epoch 5/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2571 - loss: 1.5555 - val_accuracy: 0.2537 - val_loss: 1.5580
# Epoch 6/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2609 - loss: 1.5551 - val_accuracy: 0.2535 - val_loss: 1.5577
# Epoch 7/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2634 - loss: 1.5550 - val_accuracy: 0.2547 - val_loss: 1.5575
# Epoch 8/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2598 - loss: 1.5549 - val_accuracy: 0.2527 - val_loss: 1.5574
# Epoch 9/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2616 - loss: 1.5547 - val_accuracy: 0.2554 - val_loss: 1.5586
# Epoch 10/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2606 - loss: 1.5547 - val_accuracy: 0.2539 - val_loss: 1.5576
# Epoch 11/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2618 - loss: 1.5542 - val_accuracy: 0.2549 - val_loss: 1.5576
# Epoch 12/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2620 - loss: 1.5541 - val_accuracy: 0.2559 - val_loss: 1.5575
# Epoch 13/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2624 - loss: 1.5545 - val_accuracy: 0.2534 - val_loss: 1.5577
# Epoch 14/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2619 - loss: 1.5538 - val_accuracy: 0.2543 - val_loss: 1.5578
# Epoch 15/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2621 - loss: 1.5538 - val_accuracy: 0.2505 - val_loss: 1.5581
# Epoch 16/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2632 - loss: 1.5536 - val_accuracy: 0.2533 - val_loss: 1.5576
# Epoch 17/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2637 - loss: 1.5536 - val_accuracy: 0.2548 - val_loss: 1.5580
# Epoch 18/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.2649 - loss: 1.5531 - val_accuracy: 0.2527 - val_loss: 1.5579
# Epoch 19/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2652 - loss: 1.5530 - val_accuracy: 0.2536 - val_loss: 1.5577
# Epoch 20/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2659 - loss: 1.5533 - val_accuracy: 0.2554 - val_loss: 1.5577
# Epoch 21/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2646 - loss: 1.5529 - val_accuracy: 0.2514 - val_loss: 1.5578
# Epoch 22/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2662 - loss: 1.5530 - val_accuracy: 0.2552 - val_loss: 1.5577
# Epoch 23/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2673 - loss: 1.5528 - val_accuracy: 0.2539 - val_loss: 1.5582
# Epoch 24/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2664 - loss: 1.5528 - val_accuracy: 0.2548 - val_loss: 1.5580
# Epoch 25/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2685 - loss: 1.5528 - val_accuracy: 0.2528 - val_loss: 1.5581
# Epoch 26/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2673 - loss: 1.5528 - val_accuracy: 0.2527 - val_loss: 1.5580
# Epoch 27/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2679 - loss: 1.5528 - val_accuracy: 0.2532 - val_loss: 1.5587
# Epoch 28/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2681 - loss: 1.5521 - val_accuracy: 0.2534 - val_loss: 1.5589
# Epoch 29/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2679 - loss: 1.5525 - val_accuracy: 0.2539 - val_loss: 1.5590
# Epoch 30/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2692 - loss: 1.5520 - val_accuracy: 0.2532 - val_loss: 1.5586
# Epoch 31/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2703 - loss: 1.5517 - val_accuracy: 0.2533 - val_loss: 1.5587
# Epoch 32/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2683 - loss: 1.5517 - val_accuracy: 0.2530 - val_loss: 1.5584
# Epoch 33/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2683 - loss: 1.5521 - val_accuracy: 0.2546 - val_loss: 1.5582
# Epoch 34/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2706 - loss: 1.5515 - val_accuracy: 0.2518 - val_loss: 1.5584
# Epoch 35/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2694 - loss: 1.5519 - val_accuracy: 0.2529 - val_loss: 1.5587
# Epoch 36/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2693 - loss: 1.5515 - val_accuracy: 0.2521 - val_loss: 1.5584
# Epoch 37/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2719 - loss: 1.5510 - val_accuracy: 0.2531 - val_loss: 1.5592
# Epoch 38/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2692 - loss: 1.5514 - val_accuracy: 0.2538 - val_loss: 1.5589
# Epoch 39/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2694 - loss: 1.5510 - val_accuracy: 0.2526 - val_loss: 1.5587
# Epoch 40/40
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2705 - loss: 1.5511 - val_accuracy: 0.2520 - val_loss: 1.5590

# %%
def plot_history(history, title):
    plt.figure(figsize=(12,5))

    # Accuracy
    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'], label='Entrenamiento')
    plt.plot(history.history['val_accuracy'], label='Validación')
    plt.title(f'Accuracy - {title}')
    plt.xlabel('Épocas')
    plt.ylabel('Accuracy')
    plt.legend()

    # Loss
    plt.subplot(1,2,2)
    plt.plot(history.history['loss'], label='Entrenamiento')
    plt.plot(history.history['val_loss'], label='Validación')
    plt.title(f'Loss - {title}')
    plt.xlabel('Épocas')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_history(history_basico, "MLP Básico")
plot_history(history_intermedio, "MLP Intermedio")
plot_history(history_avanzado, "MLP Avanzado")

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

def plot_confusion(model, X_test, y_test, title):
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)

    cm = confusion_matrix(y_test, y_pred_classes)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)

    disp.plot()
    plt.title(title)
    plt.show()

plot_confusion(MLP_Basico, X_test, y_test, "Matriz de Confusión - MLP Básico")
plot_confusion(MLP_Intermedio, X_test, y_test, "Matriz de Confusión - MLP Intermedio")
plot_confusion(MLP_Avanzado, X_test, y_test, "Matriz de Confusión - MLP Avanzado")
# Out:
# 1032/1032 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 1032/1032 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 1032/1032 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %%
acc_basico = MLP_Basico.evaluate(X_test, y_onehot_test, verbose=0)[1]
acc_intermedio = MLP_Intermedio.evaluate(X_test, y_onehot_test, verbose=0)[1]
acc_avanzado = MLP_Avanzado.evaluate(X_test, y_onehot_test, verbose=0)[1]

print("Accuracy MLP Básico:", acc_basico)
print("Accuracy MLP Intermedio:", acc_intermedio)
print("Accuracy MLP Avanzado:", acc_avanzado)

modelos = {
    "MLP Básico": acc_basico,
    "MLP Intermedio": acc_intermedio,
    "MLP Avanzado": acc_avanzado
}

mejor_modelo = max(modelos, key=modelos.get)
print("Mejor modelo:", mejor_modelo)
# Out:
# Accuracy MLP Básico: 0.2564242482185364
# Accuracy MLP Intermedio: 0.2534242570400238
# Accuracy MLP Avanzado: 0.25203031301498413
# Mejor modelo: MLP Básico

# %% [markdown]
# - **Actividad 4:** Sube tus cambios al repositorio, envía el link de tu repositorio a la actividad 2 de tu checkpoint 2 y contesta las preguntas de dicha actividad.
